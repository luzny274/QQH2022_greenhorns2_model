# %%
# Model vytrenuje na trenovacich datech pro ruzne lambdy a vrstvy

import argparse
import lzma
import os
import pickle
import sys
import urllib.request

import numpy as np
import sklearn.preprocessing
import sklearn.compose
import time
from sklearn.neural_network import MLPClassifier

import os

if os.name == 'nt':
    import winsound

import pandas as pd

from process_data import process_data
from process_data import reinit_properties


#       Data preprocessing
h = (3) #Moznosti rozlozeni vrstev k prohledani
ls = np.geomspace(0.3, 25.0, 50)                       #Lambdy k prohledani
folds = [2, 3, 5]

ns = range(0, 3)
ms = range(17, 27)

scores = np.zeros((len(ns), len(ms), len(folds), len(ls)))

start0 = time.time()

for n_ind in range(len(ns)):
    for m_ind in range(len(ms)):
        n = ns[n_ind]
        m = ms[m_ind]

        print("n = {}, m = {}".format(n, m))
        reinit_properties(n, m)

        #Nacteni dat
        data = pd.read_csv('data/training_data.csv')

        #Zpracovani dat, viz process_data.py
        start = time.time()
        datumy, data_for_transform, target, p, sz = process_data(data) # Zpracovani dat
        print("\nDoba transformace dat: {:.2f} s".format(time.time()-start))

        #Rozdeleni na trenovaci a testovaci indexy
        datum_trenovani = np.datetime64('2005-10-13')
        trenovaci_indexy = np.where(datumy <= datum_trenovani)[0]
        train_size = int(trenovaci_indexy[-1]) + 1
        test_size = data_for_transform.shape[0] - train_size
        # print("former train_size: ", train_size)
        # print("test_size: ", test_size)

        # print("\nn + m = ", p.n + p.m)
        # print("pocet tymu = ", p.pocet_tymu)

        #   Feature engineering
        scaler = sklearn.preprocessing.RobustScaler()

        #Nafitovani transformeru a transformace dat
        scaled_data = scaler.fit_transform(data_for_transform[:, p.num_indexy])

        data_final = scaled_data

        # print("Data transformovana", sz, p.pocet_sloupcu, data_final.shape)


        #       Trenink

        # hidden_layer_sizess = [(500)] #Moznosti rozlozeni vrstev k prohledani
        # ls = [0.5, 1.0, 2.0, 2.7, 3.0]                       #Lambdy k prohledani


        max_iter = 2000
                  
        print("________________________")
        for f_ind in range(len(folds)):
            f = folds[f_ind]
            start = time.time()
            print("\nnumber of folds:", f)

            parameters = {'alpha' : ls}

            #Vytvoreni a trenovani modelu
            mlp = MLPClassifier(random_state=1, hidden_layer_sizes=h , max_iter = max_iter)

            clf = sklearn.model_selection.GridSearchCV(mlp, parameters, cv = f, n_jobs = -1)
            # print(clf.get_params().keys())
            clf.fit(data_final, target)

            #Vypis accuracy
            print("best score: {:.3f}% ; best lambda:".format(100.0 * clf.best_score_), clf.best_params_)
            # for i in range(len(clf.cv_results_['params'])):
            #     print("{:.2f}".format(100 * clf.cv_results_['mean_test_score'][i]), clf.cv_results_['params'][i])
            print("Doba:", "{:.2f} s".format(time.time()-start))
            print("________________________")
                  
            #       Ukladani
            for i in range(len(clf.cv_results_['params'])):
                  scores[n_ind, m_ind, f_ind, i] = clf.cv_results_['mean_test_score'][i]

print("Celkova doba:", "{:.2f} s".format(time.time()-start0))

np.savez("scores.npz", ns, ms, folds, ls, scores)

if os.name == 'nt': # Pipnuti na upozorneni uzivatele, ze skript skoncil (jen pro windows)
    frequency = 500  # Set Frequency in Hz
    duration = 1000  # Set Duration in ms
    winsound.Beep(frequency, duration)
# Out:
# n = 0, m = 17
#
# Doba transformace dat: 0.37 s
# ________________________
#
# number of folds: 2
# best score: 60.092% ; best lambda: {'alpha': 2.8650408797320734}
# Doba: 6.13 s
# ________________________
#
# number of folds: 3
# best score: 60.591% ; best lambda: {'alpha': 2.3918286164678046}
# Doba: 7.98 s
# ________________________
#
# number of folds: 5
# best score: 60.758% ; best lambda: {'alpha': 2.6177636951209453}
# Doba: 13.07 s
# ________________________
# n = 0, m = 18
#
# Doba transformace dat: 0.30 s
# ________________________
#
# number of folds: 2
# best score: 60.763% ; best lambda: {'alpha': 13.29037788906916}
# Doba: 4.85 s
# ________________________
#
# number of folds: 3
# best score: 60.888% ; best lambda: {'alpha': 11.09523650556752}
# Doba: 7.35 s
# ________________________
#
# number of folds: 5
# best score: 60.909% ; best lambda: {'alpha': 4.499173455472238}
# Doba: 14.01 s
# ________________________
# n = 0, m = 19
#
# Doba transformace dat: 0.30 s
# ________________________
#
# number of folds: 2
# best score: 60.912% ; best lambda: {'alpha': 12.14330621896638}
# Doba: 4.67 s
# ________________________
#
# number of folds: 3
# best score: 60.911% ; best lambda: {'alpha': 10.137624045270647}
# Doba: 7.48 s
# ________________________
#
# number of folds: 5
# best score: 60.996% ; best lambda: {'alpha': 7.732768935620352}
# Doba: 12.97 s
# ________________________
# n = 0, m = 20
#
# Doba transformace dat: 0.32 s
# ________________________
#
# number of folds: 2
# best score: 60.825% ; best lambda: {'alpha': 8.463215818665022}
# Doba: 4.64 s
# ________________________
#
# number of folds: 3
# best score: 60.485% ; best lambda: {'alpha': 5.3893141783584335}
# Doba: 7.29 s
# ________________________
#
# number of folds: 5
# best score: 60.931% ; best lambda: {'alpha': 7.065365777370336}
# Doba: 12.98 s
# ________________________
# n = 0, m = 21
#
# Doba transformace dat: 0.31 s
# ________________________
#
# number of folds: 2
# best score: 60.713% ; best lambda: {'alpha': 13.29037788906916}
# Doba: 4.54 s
# ________________________
#
# number of folds: 3
# best score: 60.414% ; best lambda: {'alpha': 1.8244371602415512}
# Doba: 8.00 s
# ________________________
#
# number of folds: 5
# best score: 60.692% ; best lambda: {'alpha': 11.09523650556752}
# Doba: 13.24 s
# ________________________
# n = 0, m = 22
#
# Doba transformace dat: 0.38 s
# ________________________
#
# number of folds: 2
# best score: 60.607% ; best lambda: {'alpha': 9.262661614439633}
# Doba: 4.60 s
# ________________________
#
# number of folds: 3
# best score: 60.542% ; best lambda: {'alpha': 10.137624045270647}
# Doba: 7.42 s
# ________________________
#
# number of folds: 5
# best score: 60.714% ; best lambda: {'alpha': 5.3893141783584335}
# Doba: 13.24 s
# ________________________
# n = 0, m = 23
#
# Doba transformace dat: 0.37 s
# ________________________
#
# number of folds: 2
# best score: 60.974% ; best lambda: {'alpha': 9.262661614439633}
# Doba: 4.82 s
# ________________________
#
# number of folds: 3
# best score: 60.541% ; best lambda: {'alpha': 7.065365777370336}
# Doba: 7.33 s
# ________________________
#
# number of folds: 5
# best score: 60.823% ; best lambda: {'alpha': 5.898395437103501}
# Doba: 13.47 s
# ________________________
# n = 0, m = 24
#
# Doba transformace dat: 0.37 s
# ________________________
#
# number of folds: 2
# best score: 61.041% ; best lambda: {'alpha': 7.732768935620352}
# Doba: 4.64 s
# ________________________
#
# number of folds: 3
# best score: 60.888% ; best lambda: {'alpha': 6.45556513890987}
# Doba: 7.44 s
# ________________________
#
# number of folds: 5
# best score: 61.149% ; best lambda: {'alpha': 5.898395437103501}
# Doba: 13.05 s
# ________________________
# n = 0, m = 25
#
# Doba transformace dat: 0.34 s
# ________________________
#
# number of folds: 2
# best score: 60.965% ; best lambda: {'alpha': 14.545803362710002}
# Doba: 4.85 s
# ________________________
#
# number of folds: 3
# best score: 60.811% ; best lambda: {'alpha': 5.898395437103501}
# Doba: 7.36 s
# ________________________
#
# number of folds: 5
# best score: 60.724% ; best lambda: {'alpha': 4.499173455472238}
# Doba: 13.48 s
# ________________________
# n = 0, m = 26
#
# Doba transformace dat: 0.35 s
# ________________________
#
# number of folds: 2
# best score: 61.078% ; best lambda: {'alpha': 13.29037788906916}
# Doba: 4.79 s
# ________________________
#
# number of folds: 3
# best score: 60.283% ; best lambda: {'alpha': 0.7398183209900018}
# Doba: 8.06 s
# ________________________
#
# number of folds: 5
# best score: 60.967% ; best lambda: {'alpha': 5.3893141783584335}
# Doba: 13.11 s
# ________________________
# n = 1, m = 17
#
# Doba transformace dat: 1.14 s
# ________________________
#
# number of folds: 2
# best score: 60.448% ; best lambda: {'alpha': 7.732768935620352}
# Doba: 6.81 s
# ________________________
#
# number of folds: 3
# best score: 60.365% ; best lambda: {'alpha': 13.29037788906916}
# Doba: 11.82 s
# ________________________
#
# number of folds: 5
# best score: 60.574% ; best lambda: {'alpha': 3.135676171930671}
# Doba: 20.18 s
# ________________________
# n = 1, m = 18
#
# Doba transformace dat: 1.09 s
# ________________________
#
# number of folds: 2
# best score: 60.279% ; best lambda: {'alpha': 17.423623488647806}
# Doba: 6.82 s
# ________________________
#
# number of folds: 3
# best score: 60.447% ; best lambda: {'alpha': 13.29037788906916}
# Doba: 11.67 s
# ________________________
#
# number of folds: 5
# best score: 60.596% ; best lambda: {'alpha': 10.137624045270647}
# Doba: 20.31 s
# ________________________
# n = 1, m = 19
#
# Doba transformace dat: 1.07 s
# ________________________
#
# number of folds: 2
# best score: 60.272% ; best lambda: {'alpha': 9.262661614439633}
# Doba: 7.30 s
# ________________________
#
# number of folds: 3
# best score: 60.612% ; best lambda: {'alpha': 11.09523650556752}
# Doba: 12.20 s
# ________________________
#
# number of folds: 5
# best score: 60.570% ; best lambda: {'alpha': 5.898395437103501}
# Doba: 19.22 s
# ________________________
# n = 1, m = 20
#
# Doba transformace dat: 1.11 s
# ________________________
#
# number of folds: 2
# best score: 60.179% ; best lambda: {'alpha': 8.463215818665022}
# Doba: 6.37 s
# ________________________
#
# number of folds: 3
# best score: 60.414% ; best lambda: {'alpha': 12.14330621896638}
# Doba: 11.19 s
# ________________________
#
# number of folds: 5
# best score: 60.393% ; best lambda: {'alpha': 11.09523650556752}
# Doba: 18.13 s
# ________________________
# n = 1, m = 21
#
# Doba transformace dat: 1.02 s
# ________________________
#
# number of folds: 2
# best score: 60.392% ; best lambda: {'alpha': 15.919817873699632}
# Doba: 5.99 s
# ________________________
#
# number of folds: 3
# best score: 60.391% ; best lambda: {'alpha': 12.14330621896638}
# Doba: 11.29 s
# ________________________
#
# number of folds: 5
# best score: 60.392% ; best lambda: {'alpha': 13.29037788906916}
# Doba: 17.15 s
# ________________________
# n = 1, m = 22
#
# Doba transformace dat: 0.95 s
# ________________________
#
# number of folds: 2
# best score: 60.195% ; best lambda: {'alpha': 17.423623488647806}
# Doba: 6.12 s
# ________________________
#
# number of folds: 3
# best score: 60.411% ; best lambda: {'alpha': 10.137624045270647}
# Doba: 9.80 s
# ________________________
#
# number of folds: 5
# best score: 60.346% ; best lambda: {'alpha': 14.545803362710002}
# Doba: 17.45 s
# ________________________
# n = 1, m = 23
#
# Doba transformace dat: 0.93 s
# ________________________
#
# number of folds: 2
# best score: 60.257% ; best lambda: {'alpha': 14.545803362710002}
# Doba: 6.15 s
# ________________________
#
# number of folds: 3
# best score: 60.649% ; best lambda: {'alpha': 8.463215818665022}
# Doba: 10.26 s
# ________________________
#
# number of folds: 5
# best score: 60.300% ; best lambda: {'alpha': 12.14330621896638}
# Doba: 17.85 s
# ________________________
# n = 1, m = 24
#
# Doba transformace dat: 0.87 s
# ________________________
#
# number of folds: 2
# best score: 60.373% ; best lambda: {'alpha': 13.29037788906916}
# Doba: 6.25 s
# ________________________
#
# number of folds: 3
# best score: 60.482% ; best lambda: {'alpha': 9.262661614439633}
# Doba: 10.81 s
# ________________________
#
# number of folds: 5
# best score: 60.175% ; best lambda: {'alpha': 11.09523650556752}
# Doba: 17.09 s
# ________________________
# n = 1, m = 25
#
# Doba transformace dat: 0.85 s
# ________________________
#
# number of folds: 2
# best score: 60.239% ; best lambda: {'alpha': 8.463215818665022}
# Doba: 6.05 s
# ________________________
#
# number of folds: 3
# best score: 60.305% ; best lambda: {'alpha': 11.09523650556752}
# Doba: 10.45 s
# ________________________
#
# number of folds: 5
# best score: 60.217% ; best lambda: {'alpha': 3.135676171930671}
# Doba: 17.94 s
# ________________________
# n = 1, m = 26
#
# Doba transformace dat: 0.85 s
# ________________________
#
# number of folds: 2
# best score: 60.138% ; best lambda: {'alpha': 15.919817873699632}
# Doba: 6.01 s
# ________________________
#
# number of folds: 3
# best score: 60.160% ; best lambda: {'alpha': 12.14330621896638}
# Doba: 10.22 s
# ________________________
#
# number of folds: 5
# best score: 60.071% ; best lambda: {'alpha': 13.29037788906916}
# Doba: 16.50 s
# ________________________
# n = 2, m = 17
#
# Doba transformace dat: 1.44 s
# ________________________
#
# number of folds: 2
# best score: 60.870% ; best lambda: {'alpha': 12.14330621896638}
# Doba: 11.34 s
# ________________________
#
# number of folds: 3
# best score: 60.637% ; best lambda: {'alpha': 12.14330621896638}
# Doba: 17.15 s
# ________________________
#
# number of folds: 5
# best score: 60.659% ; best lambda: {'alpha': 11.09523650556752}
# Doba: 28.80 s
# ________________________
# n = 2, m = 18
#
# Doba transformace dat: 1.56 s
# ________________________
#
# number of folds: 2
# best score: 60.804% ; best lambda: {'alpha': 12.14330621896638}
# Doba: 11.31 s
# ________________________
#
# number of folds: 3
# best score: 60.591% ; best lambda: {'alpha': 12.14330621896638}
# Doba: 17.58 s
# ________________________
#
# number of folds: 5
# best score: 60.485% ; best lambda: {'alpha': 8.463215818665022}
# Doba: 29.35 s
# ________________________
# n = 2, m = 19
#
# Doba transformace dat: 1.42 s
# ________________________
#
# number of folds: 2
# best score: 60.671% ; best lambda: {'alpha': 12.14330621896638}
# Doba: 11.38 s
# ________________________
#
# number of folds: 3
# best score: 60.606% ; best lambda: {'alpha': 10.137624045270647}
# Doba: 16.88 s
# ________________________
#
# number of folds: 5
# best score: 60.628% ; best lambda: {'alpha': 12.14330621896638}
# Doba: 29.53 s
# ________________________
# n = 2, m = 20
#
# Doba transformace dat: 1.37 s
# ________________________
#
# number of folds: 2
# best score: 60.650% ; best lambda: {'alpha': 8.463215818665022}
# Doba: 11.30 s
# ________________________
#
# number of folds: 3
# best score: 60.650% ; best lambda: {'alpha': 6.45556513890987}
# Doba: 17.18 s
# ________________________
#
# number of folds: 5
# best score: 60.779% ; best lambda: {'alpha': 12.14330621896638}
# Doba: 30.27 s
# ________________________
# n = 2, m = 21
#
# Doba transformace dat: 1.37 s
# ________________________
#
# number of folds: 2
# best score: 60.584% ; best lambda: {'alpha': 11.09523650556752}
# Doba: 11.14 s
# ________________________
#
# number of folds: 3
# best score: 60.801% ; best lambda: {'alpha': 11.09523650556752}
# Doba: 17.67 s
# ________________________
#
# number of folds: 5
# best score: 60.758% ; best lambda: {'alpha': 12.14330621896638}
# Doba: 30.04 s
# ________________________
# n = 2, m = 22
#
# Doba transformace dat: 1.37 s
# ________________________
#
# number of folds: 2
# best score: 60.976% ; best lambda: {'alpha': 13.29037788906916}
# Doba: 11.62 s
# ________________________
#
# number of folds: 3
# best score: 61.041% ; best lambda: {'alpha': 11.09523650556752}
# Doba: 17.64 s
# ________________________
#
# number of folds: 5
# best score: 61.063% ; best lambda: {'alpha': 11.09523650556752}
# Doba: 30.68 s
# ________________________
# n = 2, m = 23
#
# Doba transformace dat: 1.36 s
# ________________________
#
# number of folds: 2
# best score: 60.724% ; best lambda: {'alpha': 10.137624045270647}
# Doba: 11.41 s
# ________________________
#
# number of folds: 3
# best score: 60.680% ; best lambda: {'alpha': 10.137624045270647}
# Doba: 18.05 s
# ________________________
#
# number of folds: 5
# best score: 60.877% ; best lambda: {'alpha': 8.463215818665022}
# Doba: 30.91 s
# ________________________
# n = 2, m = 24
#
# Doba transformace dat: 1.34 s
# ________________________
#
# number of folds: 2
# best score: 60.526% ; best lambda: {'alpha': 10.137624045270647}
# Doba: 11.70 s
# ________________________
#
# number of folds: 3
# best score: 60.592% ; best lambda: {'alpha': 4.924170924579125}
# Doba: 18.80 s
# ________________________
#
# number of folds: 5
# best score: 60.835% ; best lambda: {'alpha': 7.065365777370336}
# Doba: 31.45 s
# ________________________
# n = 2, m = 25
#
# Doba transformace dat: 1.37 s
# ________________________
#
# number of folds: 2
# best score: 60.382% ; best lambda: {'alpha': 10.137624045270647}
# Doba: 11.52 s
# ________________________
#
# number of folds: 3
# best score: 60.427% ; best lambda: {'alpha': 13.29037788906916}
# Doba: 17.82 s
# ________________________
#
# number of folds: 5
# best score: 60.494% ; best lambda: {'alpha': 9.262661614439633}
# Doba: 30.60 s
# ________________________
# n = 2, m = 26
#
# Doba transformace dat: 1.48 s
# ________________________
#
# number of folds: 2
# best score: 60.465% ; best lambda: {'alpha': 8.463215818665022}
# Doba: 11.94 s
# ________________________
#
# number of folds: 3
# best score: 60.242% ; best lambda: {'alpha': 9.262661614439633}
# Doba: 17.24 s
# ________________________
#
# number of folds: 5
# best score: 60.711% ; best lambda: {'alpha': 12.14330621896638}
# Doba: 28.98 s
# ________________________
# Celkova doba: 1231.29 s

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [10, 5]

# %%
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

import matplotlib.pyplot as plt

loaded_arrays = np.load("scores.npz")
ns     = loaded_arrays['arr_0']
ms     = loaded_arrays['arr_1']
folds  = loaded_arrays['arr_2']
ls     = loaded_arrays['arr_3']
scores = loaded_arrays['arr_4']

axis_names = ["n","m","folds","lambda"]
list_vars = [ns, ms, folds, ls]

best_inds = np.unravel_index(np.argmax(scores, axis=None), scores.shape)

#Print best globally
best_params = []
for i in range(4):
    best_params.append(list_vars[i][best_inds[i]])
    
print(scores.max(), best_params)

#Print best for each fold
for ii in range(len(folds)):
    iiarr = scores[:, :, ii, :]
    iibest_inds = np.unravel_index(np.argmax(iiarr, axis=None), iiarr.shape)

    iibest_params = []
    for i in range(3):
        ind = i if i < 2 else i + 1
        iibest_params.append(list_vars[ind][iibest_inds[i]])
    print("f:", list_vars[2][ii], iiarr.max(), iibest_params)


def plot_heatmap_slice(axis_slice1, axis_slice2, axis_top):
    print("axis_slice1:", axis_names[axis_slice1])
    axis_top_pom = axis_top + 1 if axis_top >= axis_slice1 else axis_top
    axis_slice2_pom = axis_slice2 + 1 if axis_slice2 >= axis_slice1 else axis_slice2
    axis_slice2_pom = axis_slice2_pom + 1 if axis_slice2_pom >= axis_top else axis_slice2_pom
    
    print("axis_slice2:", axis_names[axis_slice2_pom])
    print("axis_top:", axis_names[axis_top_pom])
    # slc = scores[n_ind, m_ind, f_ind, i]
    
    all_axis = range(4)
    last_axis = np.delete(all_axis, [axis_slice1, axis_slice2_pom, axis_top_pom])[0]
    print("last axis:", axis_names[last_axis])
    
    def implt_finally(sliced_value1, sliced_value2):
        print("sliced_value1:", list_vars[axis_slice1][sliced_value1])
        print("sliced_value2:", list_vars[axis_slice2_pom][sliced_value2])
        
        sliced1 = scores.take(indices=sliced_value1, axis=axis_slice1)
        topped = np.max(sliced1, axis = axis_top)
        plt.subplot(2, 2, 1)
        plt.imshow(topped, cmap='Reds')
        plt.title("Max score - heatmap")
        plt.colorbar()
        
        sliced2 = topped.take(indices=sliced_value2, axis=axis_slice2)
        plt.subplot(2, 2, 2)
        plt.plot(sliced2)
        plt.title("Max score - plot")
        plt.show()
        
        topped = np.argmax(sliced1, axis = axis_top)
        plt.subplot(2, 2, 3)
        plt.imshow(topped, cmap='Reds')
        plt.title("Argmax score - heatmap")
        plt.colorbar()
        
        sliced2 = topped.take(indices=sliced_value2, axis=axis_slice2)
        plt.subplot(2, 2, 4)
        plt.plot(sliced2)
        plt.title("Argmax score - plot")
        plt.show()
        
        
    interact(implt_finally, sliced_value1=widgets.IntSlider(min=0, max=scores.shape[axis_slice1] - 1, step=1), sliced_value2=widgets.IntSlider(min=0, max=scores.shape[axis_slice2_pom] - 1, step=1))
    
    
    
interact(plot_heatmap_slice, axis_slice1=widgets.IntSlider(min=0, max=3, value = 2, step=1), axis_top=widgets.IntSlider(min=0, max=2, value = 2, step=1), axis_slice2=widgets.IntSlider(min=0, max=1, step=1));
# Out:
# 0.6114937378651134 [0, 24, 5, 5.898395437103501]
# f: 2 0.610778868539682 [0, 26, 13.29037788906916]
# f: 3 0.6104115526753556 [2, 22, 11.09523650556752]
# f: 5 0.6114937378651134 [0, 24, 5.898395437103501]
# interactive(children=(IntSlider(value=2, description='axis_slice1', max=3), IntSlider(value=0, description='ax…
